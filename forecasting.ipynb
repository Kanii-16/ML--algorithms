# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("/content/store_sales.csv")
print(df.head())
# Out:
#          date  store   sales  promo  holiday
# 0  2022-01-01      1  184.78      0        0
# 1  2022-01-02      1  192.62      0        0
# 2  2022-01-03      1  212.68      0        0
# 3  2022-01-04      1  249.58      1        0
# 4  2022-01-05      1  223.50      0        0

# %%
df['date'] = pd.to_datetime(df['date'])

df['Month'] = df['date'].dt.month

X = df[['Month']]
y = df['sales']

# %%
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
future_months = [[6], [7], [8]]

forecast = model.predict(future_months)

for month, sales in zip(future_months, forecast):
    print("Month:", month[0], "Predicted Sales:", round(sales, 2))
# Out:
# Month: 6 Predicted Sales: 227.69
# Month: 7 Predicted Sales: 229.11
# Month: 8 Predicted Sales: 230.52
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X))
plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Sales Forecasting")
plt.show()
